# %%
from nordmacpy import VpnManager

# %%
import os

# These are both 24-character strings from the NordVPN dashoard. See the README for more details.
USERNAME = os.environ["NORDVPN_SERVICE_CREDENTIALS_USERNAME"]
PASSWORD = os.environ["NORDVPN_SERVICE_CREDENTIALS_PASSWORD"]

# %% [markdown]
# Example: basic connection API

# %%
# Downloads the config files from NordVPN if we don't already have them
mgr = VpnManager(username=USERNAME, password=PASSWORD)
# Out:
# Downloading config files...
# Config files downloaded successfully

# %%
mgr.connect_to_random_vpn()
# Out:
# Connected to VPN in Charlotte, North Carolina, US
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='192.145.117.105', city='Charlotte', region='North Carolina', country='US', loc='35.2271,-80.8431', org='AS141039 PacketHub S.A.', postal='28202', timezone='America/New_York', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='us8476', connection_type=<ConnectionType.UDP: 'udp'>))

# %%
# This is called when we open another connection,
# or when the VpnManager instance goes out of scope.
# But we can also call it manually.
mgr.disconnect()

# %% [markdown]
# Example: we close the connection when the VpnManager instance goes out of scope

# %%
def run():
    m = VpnManager(username=USERNAME, password=PASSWORD)
    m.connect_to_random_vpn()

run()
# Out:
# Connected to VPN in New York City, New York, US
# Disconnecting from VPN on deconstruction of the VpnManager object class so we don't leak threads...
#  (If you want to have this VPN connection remain open you must keep the instance of the VpnManager object alive)
# Disconnected from VPN

# %% [markdown]
# Example: country/hostname/etc filters for VPN server selection

# %%
mgr.connect_to_random_vpn(country_blacklist=["us"])
# Out:
# Filtered out 6222 servers due to country blacklist
# Connected to VPN in London, England, GB
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='194.35.235.5', city='London', region='England', country='GB', loc='51.5085,-0.1257', org='AS62240 Clouvider', postal='E1W', timezone='Europe/London', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='uk2599', connection_type=<ConnectionType.UDP: 'udp'>))

# %%
mgr.connect_to_random_vpn(country_whitelist=["us"])
# Out:
# Filtered out 11595 servers due to country whitelist
# Connected to VPN in San Jose, California, US
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='185.187.168.98', city='San Jose', region='California', country='US', loc='37.3394,-121.8950', org='AS212238 Datacamp Limited', postal='95025', timezone='America/Los_Angeles', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='us9675', connection_type=<ConnectionType.TCP: 'tcp'>))

# %%
mgr.connect_to_random_vpn(only_tcp=True, only_udp=False)
# Out:
# Connected to VPN in Rome, Lazio, IT
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='85.190.232.182', city='Rome', region='Lazio', country='IT', loc='41.8919,12.5113', org='AS207137 PacketHub S.A.', postal='00118', timezone='Europe/Rome', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='it259', connection_type=<ConnectionType.TCP: 'tcp'>))

# %%
mgr.connect_to_random_vpn(avoid_last_n_servers=100)
# Out:
# History: {VpnConfig(server_id='us11837', connection_type=<ConnectionType.TCP: 'tcp'>), VpnConfig(server_id='jp529', connection_type=<ConnectionType.UDP: 'udp'>)}
# Configs: VpnConfig(server_id='uk2591', connection_type=<ConnectionType.TCP: 'tcp'>)
# Filtered out 2 servers due to avoid last 100 servers
# Connected to VPN in Seoul, Seoul, KR
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='160.238.37.69', city='Seoul', region='Seoul', country='KR', loc='37.5660,126.9784', org='AS147049 PacketHub S.A.', postal='03141', timezone='Asia/Seoul', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='kr121', connection_type=<ConnectionType.UDP: 'udp'>))

# %%
host_whitelist = mgr.get_available_servers()[:5]
host_whitelist

# %%
# You can pass in the VpnConfig objects you want to choose from
mgr.connect_to_random_vpn(host_whitelist=host_whitelist)

# %%
# The whitelist can also contain strings, which will be converted to VpnConfig objects
mgr.connect_to_random_vpn(host_whitelist=["uk2591.nordvpn.com.tcp"])
# Out:
# Filtered out 17816 servers due to host whitelist
# Connected to VPN in London, England, GB
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='103.214.47.164', city='London', region='England', country='GB', loc='51.5085,-0.1257', org='AS62240 Clouvider', postal='E1W', timezone='Europe/London', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='uk2591', connection_type=<ConnectionType.TCP: 'tcp'>))

# %%
# You can also blacklist servers
host_blacklist = host_whitelist

# %%
mgr.connect_to_random_vpn(host_blacklist=host_blacklist)
# Out:
# Filtered out 5 servers due to host blacklist
# Connected to VPN in Tirana, Tirana, AL
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='147.93.215.188', city='Tirana', region='Tirana', country='AL', loc='41.3274,19.8187', org='AS136787 PacketHub S.A.', postal='1700', timezone='Europe/Tirane', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='al79', connection_type=<ConnectionType.TCP: 'tcp'>))

# %%
# Blacklist strings work too
mgr.connect_to_random_vpn(host_blacklist=["uk2591.nordvpn.com.tcp"])
# Out:
# Filtered out 1 servers due to host blacklist
# Connected to VPN in Rome, Lazio, IT
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='85.190.233.221', city='Rome', region='Lazio', country='IT', loc='41.8919,12.5113', org='AS207137 PacketHub S.A.', postal='00118', timezone='Europe/Rome', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='it283', connection_type=<ConnectionType.TCP: 'tcp'>))

# %% [markdown]
# Example: checking available servers, and countries

# %%
# You can filter by connection type (defaults to no filters)
# Optional filters:
# >>> mgr.get_available_servers(only_tcp=False, only_udp=False)
mgr.get_available_servers()
# Out:
# [VpnConfig(server_id='uk2591', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='mx92', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='at98', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12275', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2715', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8519', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='cz121', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ch378', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr821', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='kr112', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2562', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='bg75', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12002', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12286', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8104', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='it377', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1653', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2308', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us-ca105', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8380', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='in156', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='rw2', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='it384', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11828', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8373', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au649', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='mr2', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='at132', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9408', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2106', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11851', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='pl269', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nl1118', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12088', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='mx124', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8560', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8717', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr858', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ch301', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='cz158', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9015', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us4999', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2868', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='cr54', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='hk203', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='es224', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='sg532', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='id47', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1628', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='be222', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us6946', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nz105', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1137', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11522', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1340', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11755', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9988', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au934', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de920', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9902', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10259', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us5508', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1339', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='jp695', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2811', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr552', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10644', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='jp666', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10433', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ua58', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='hk289', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1651', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1218', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1885', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11489', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9823', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='br97', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='no241', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10378', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1876', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10512', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='jp747', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1770', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ae67', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2930', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1783', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='jp530', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='es172', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nl865', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='pt145', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1709', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nl896', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2949', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10598', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='es181', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='jp549', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='hk322', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11674', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1261', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au815', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de801', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ie132', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10176', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='be174', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='de1292', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10301', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11687', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us6867', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='no238', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us10185', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='al83', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9529', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au595', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11970', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2027', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr1082', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au711', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='al70', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2250', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr1071', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us6763', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11983', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr979', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='hr49', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='gr74', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nl1039', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9343', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr900', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12123', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2443', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='nl718', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us6307', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk1887', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2634', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us12354', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk888', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1781', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9550', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us11909', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1505', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='au768', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us8252', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='se631', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='it256', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ch433', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='pl146', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='uk2229', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='ca1772', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='fr1008', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='us9727', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='dk234', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='il71', connection_type=<ConnectionType.TCP: 'tcp'>),
#  VpnConfig(server_id='
', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='bz1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='bz1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='bz2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'td': [VpnConfig(server_id='td2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='td1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='td1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='td2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'kw': [VpnConfig(server_id='kw1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='kw2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='kw2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='kw1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'af': [VpnConfig(server_id='af4', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='af1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='af2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='af3', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='af3', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='af2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='af1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='af4', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'se-dk': [VpnConfig(server_id='se-dk1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-dk4', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-dk2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-dk3', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-dk3', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='se-dk2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='se-dk4', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='se-dk1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'pa': [VpnConfig(server_id='pa1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pa2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pa3', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pa3', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='pa2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='pa1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'gh': [VpnConfig(server_id='gh1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='gh2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='gh2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='gh1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'jo': [VpnConfig(server_id='jo2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='jo1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='jo1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='jo2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'la': [VpnConfig(server_id='la2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='la1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='la1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='la2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'lk': [VpnConfig(server_id='lk2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='lk1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='lk1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='lk2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'sn': [VpnConfig(server_id='sn2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='sn1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='sn1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='sn2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'iq': [VpnConfig(server_id='iq1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='iq2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='iq2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='iq1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'mm': [VpnConfig(server_id='mm2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='mm1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='mm1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='mm2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  've': [VpnConfig(server_id='ve1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ve2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ve2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ve1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'pk': [VpnConfig(server_id='pk1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pk2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pk2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='pk1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'se-onion': [VpnConfig(server_id='se-onion1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-onion2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='se-onion2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='se-onion1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'hk-tw': [VpnConfig(server_id='hk-tw3', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='hk-tw3', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'dz': [VpnConfig(server_id='dz3', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='dz5', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='dz4', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='dz1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='dz1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='dz4', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='dz5', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='dz3', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'tn': [VpnConfig(server_id='tn2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='tn1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='tn1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='tn2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'me': [VpnConfig(server_id='me2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='me1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='me1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='me2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'pr': [VpnConfig(server_id='pr1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pr2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='pr2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='pr1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'jm': [VpnConfig(server_id='jm2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='jm1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='jm1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='jm2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'hn': [VpnConfig(server_id='hn1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='hn2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='hn2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='hn1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'kz': [VpnConfig(server_id='kz2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='kz1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='kz1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='kz2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'az': [VpnConfig(server_id='az2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='az1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='az1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='az2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'gt': [VpnConfig(server_id='gt2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='gt1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='gt1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='gt2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'uy': [VpnConfig(server_id='uy2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='uy1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='uy1', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='uy2', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'bn': [VpnConfig(server_id='bn1', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='bn2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='bn2', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='bn1', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'md': [VpnConfig(server_id='md21', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='md19', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='md20', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='md20', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='md21', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='md19', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'nl-ch': [VpnConfig(server_id='nl-ch19', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-ch17', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-ch20', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-ch18', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-ch17', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='nl-ch20', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='nl-ch18', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='nl-ch19', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'ch-nl': [VpnConfig(server_id='ch-nl19', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-nl17', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-nl18', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-nl20', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-nl17', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-nl18', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-nl20', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-nl19', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'nl-onion': [VpnConfig(server_id='nl-onion7', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-onion6', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='nl-onion6', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='nl-onion7', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'ch-se': [VpnConfig(server_id='ch-se20', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-se18', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-se17', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-se19', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-se19', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-se20', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-se18', connection_type=<ConnectionType.UDP: 'udp'>),
#   VpnConfig(server_id='ch-se17', connection_type=<ConnectionType.UDP: 'udp'>)],
#  'ch-onion': [VpnConfig(server_id='ch-onion2', connection_type=<ConnectionType.TCP: 'tcp'>),
#   VpnConfig(server_id='ch-onion2', connection_type=<ConnectionType.UDP: 'udp'>)]}

# %%
print("Countries (and pseudo-countries):")
list(mgr.get_available_servers_by_country())
# Out:
# Countries (and pseudo-countries):
# ['uk',
#  'mx',
#  'at',
#  'us',
#  'cz',
#  'ch',
#  'fr',
#  'kr',
#  'bg',
#  'it',
#  'ca',
#  'us-ca',
#  'in',
#  'rw',
#  'au',
#  'mr',
#  'pl',
#  'nl',
#  'cr',
#  'hk',
#  'es',
#  'sg',
#  'id',
#  'be',
#  'nz',
#  'de',
#  'jp',
#  'ua',
#  'br',
#  'no',
#  'ae',
#  'pt',
#  'ie',
#  'al',
#  'hr',
#  'gr',
#  'se',
#  'dk',
#  'il',
#  'ca-us',
#  'tr',
#  'bh',
#  'za',
#  'tw',
#  'lu',
#  'vn',
#  'tw-hk',
#  'fj',
#  'ge',
#  'lv',
#  'mc',
#  'cy',
#  'tg',
#  'km',
#  'so',
#  'lt',
#  'th',
#  'am',
#  'ro',
#  'gl',
#  'rs',
#  'sk',
#  'pe',
#  'sv',
#  'fi',
#  'gu',
#  'fr-ch',
#  'bo',
#  'hu',
#  'se-nl',
#  'eg',
#  'ci',
#  'se-ch',
#  'im',
#  'ar',
#  'mu',
#  'mz',
#  'ba',
#  'ee',
#  'nl-se',
#  'lb',
#  'si',
#  'ke',
#  'se-uk',
#  'np',
#  'fr-uk',
#  'nl-uk',
#  'mn',
#  'ma',
#  'tj',
#  'uk-nl',
#  'cl',
#  'ao',
#  'ph',
#  'py',
#  'bt',
#  'co',
#  'do',
#  'ch-fr',
#  'tt',
#  'qa',
#  'is',
#  'ad',
#  'mt',
#  'pg',
#  'my',
#  'ly',
#  'bs',
#  'ng',
#  'ye',
#  'kh',
#  'je',
#  'uk-fr',
#  'et',
#  'uz',
#  'bm',
#  'bb',
#  'ky',
#  'bd',
#  'mk',
#  'sr',
#  'dk-se',
#  'tz',
#  'ec',
#  'li',
#  'uk-se',
#  'bz',
#  'td',
#  'kw',
#  'af',
#  'se-dk',
#  'pa',
#  'gh',
#  'jo',
#  'la',
#  'lk',
#  'sn',
#  'iq',
#  'mm',
#  've',
#  'pk',
#  'se-onion',
#  'hk-tw',
#  'dz',
#  'tn',
#  'me',
#  'pr',
#  'jm',
#  'hn',
#  'kz',
#  'az',
#  'gt',
#  'uy',
#  'bn',
#  'md',
#  'nl-ch',
#  'ch-nl',
#  'nl-onion',
#  'ch-se',
#  'ch-onion']

# %% [markdown]
# Example: You can connect directly to a VPN of your choosing as well

# %%
random_server = mgr.get_available_servers(only_tcp=False, only_udp=False)[1234]
print("Connecting to server:", random_server)
mgr.connect_to_vpn(server_id=random_server.server_id, connection_type=random_server.connection_type)
# Out:
# VpnConnectionResult(ok=True, ip_info=IPInfo(ip='212.32.92.42', city='Kelsterbach', region='Hesse', country='DE', loc='50.0613,8.5292', org='AS212238 Datacamp Limited', postal='65451', timezone='Europe/Berlin', readme=HttpUrl('https://ipinfo.io/missingauth')), config=VpnConfig(server_id='tj2', connection_type=<ConnectionType.TCP: 'tcp'>))
